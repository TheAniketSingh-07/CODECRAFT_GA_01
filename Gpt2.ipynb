# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAniketSingh-07/CODECRAFT_GA_01/blob/main/Gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
from IPython.display import display
import ipywidgets as widgets

# Load your fine-tuned model
generator = pipeline("text-generation",
                     model="/content/gpt2-custom",
                     tokenizer="/content/gpt2-custom")

# Create text input box
input_box = widgets.Text(
    value='',
    placeholder='Type your question or prompt here...',
    description='Prompt:',
    layout=widgets.Layout(width='80%')
)

# Create output area
output_area = widgets.Output()

# Define button click function
def on_button_click(b):
    output_area.clear_output()
    prompt = input_box.value.strip()
    if prompt == "":
        with output_area:
            print("❗ Please enter a prompt.")
        return
    # Generate output
    response = generator(prompt,
                         max_new_tokens=100,
                         do_sample=True,
                         temperature=0.9,
                         top_k=50,
                         truncation=True)

    with output_area:
        print(f"\n🟢 Prompt: {prompt}\n")
        print("📝 Response:")
        print(response[0]['generated_text'])

# Create the generate button
generate_button = widgets.Button(
    description='Generate Text',
    button_style='success'
)
generate_button.on_click(on_button_click)

# Display the UI
display(input_box, generate_button, output_area)
# Out:
# Device set to use cpu
# Text(value='', description='Prompt:', layout=Layout(width='80%'), placeholder='Type your question or prompt he…
# Button(button_style='success', description='Generate Text', style=ButtonStyle())
# Output()

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="/content/gpt2-custom", tokenizer="/content/gpt2-custom")

prompt = "Write a thank you message for my best friend"
output = generator(prompt, max_length=100, num_return_sequences=1, truncation=True)

print(output[0]['generated_text'])
# Out:
# Device set to use cpu
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Write a thank you message for my best friend.
# Dear Best Friend,
#
# Thank you for never judging me and always lifting me up. You’re a blessing I’ll never take for granted.
#
# Forever grateful,
# Aniket

# %%
model.save_pretrained("/content/gpt2-custom")
tokenizer.save_pretrained("/content/gpt2-custom")
# Out:
# ('/content/gpt2-custom/tokenizer_config.json',
#  '/content/gpt2-custom/special_tokens_map.json',
#  '/content/gpt2-custom/vocab.json',
#  '/content/gpt2-custom/merges.txt',
#  '/content/gpt2-custom/added_tokens.json',
#  '/content/gpt2-custom/tokenizer.json')

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from transformers import GPT2LMHeadModel, Trainer, TrainingArguments

model = GPT2LMHeadModel.from_pretrained("gpt2")

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_steps=50,
    save_steps=200,
    warmup_steps=50,
    weight_decay=0.01,
    logging_dir="./logs"
)

# Add labels to the dataset
tokenized = tokenized.add_column("labels", tokenized["input_ids"])

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized,
    eval_dataset=tokenized,  # You can split for validation
)

trainer.train()
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1395: FutureWarning: promote has been superseded by promote_options='default'.
#   block_group = [InMemoryTable(cls._concat_blocks(list(block_group), axis=axis))]
# /usr/local/lib/python3.11/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='699' max='735' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [699/735 3:15:11 < 10:04, 0.06 it/s, Epoch 2.85/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
# ...

# %%
from datasets import Dataset
from transformers import AutoTokenizer

# Load dataset from text
with open("Dataset.txt", "r", encoding="utf-8") as f:
    data = f.read().split("=== ")

# Reformat
records = [{"text": "=== " + item.strip()} for item in data if item.strip()]
dataset = Dataset.from_list(records)

# Tokenize
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token # Add padding token
def tokenize(batch): return tokenizer(batch["text"], truncation=True, padding="max_length", max_length=512)
tokenized = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/490 [00:00<?, ? examples/s]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d17bf30c-c0a7-4545-bde6-f249e370af20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d17bf30c-c0a7-4545-bde6-f249e370af20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install transformers datasets accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...
